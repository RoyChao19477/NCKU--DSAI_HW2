# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
sns.set( style="ticks" )

# %%
df_train = pd.read_csv("data/1_training_set.csv", index_col=0)
df_test = pd.read_csv("data/2_testing_set.csv", index_col=0)

train_x = df_train.drop(columns='PRED')
train_y = df_train['PRED']

test_x = df_test.drop(columns='PRED')
test_y = df_test['PRED']

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

l = len(test_x)
x = np.arange(0, l)

y_true = []
y_pred = []

for idx in range( l ):
  y_true.append( test_y.iloc[idx] )
  #y_pred.append( clf.predict( test_x.iloc[idx].values.reshape(1, -1))[0] )
  y_pred = [154.709342343804, 156.39710032244122, 155.5446491921158, 153.71507795566927, 153.82290125175385, 155.09836735382882, 155.67717893656362, 156.351647841084, 154.169994763416, 154.3276758054855, 152.9185405974185, 153.7581540709613, 153.81507508403854, 153.49016958446276, 151.94294255195808, 152.52133998706398, 152.88764290258564, 153.73069680847036, 154.24697254250668]
  

fig, ax = plt.subplots()
sns.lineplot(x=x, y=y_true, ax=ax)
sns.lineplot(x=x, y=y_pred, ax=ax)

print(f"MSE: {mean_squared_error(y_true, y_pred) / len(y_true)}") 
print(f"MAE: {mean_absolute_error(y_true, y_pred) / len(y_true)}")
# Out:
# MSE: 0.021159161178182617
# MAE: 0.02474717209948494
